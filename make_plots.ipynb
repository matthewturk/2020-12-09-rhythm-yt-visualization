# %%
import yt

# %%
ds = yt.load_sample("IsolatedGalaxy")
p = ds.r[:].integrate("density", axis="z").plot()
# Out:
# yt : [INFO     ] 2020-12-09 08:23:02,221 Files located at /home/mturk/.cache/yt/IsolatedGalaxy.tar.gz.untar/IsolatedGalaxy/galaxy0030/galaxy0030
# yt : [INFO     ] 2020-12-09 08:23:02,222 Default to loading galaxy0030/galaxy0030 for IsolatedGalaxy dataset
# yt : [INFO     ] 2020-12-09 08:23:02,341 Parameters: current_time              = 0.0060000200028298
# yt : [INFO     ] 2020-12-09 08:23:02,342 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2020-12-09 08:23:02,343 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2020-12-09 08:23:02,344 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2020-12-09 08:23:02,345 Parameters: cosmological_simulation   = 0.0
# Parsing Hierarchy : 100%|██████████| 173/173 [00:00<00:00, 7489.91it/s]
# yt : [INFO     ] 2020-12-09 08:23:02,385 Gathering a field list (this may take a moment.)
# yt : [INFO     ] 2020-12-09 08:23:05,736 Projection completed
# ...

# %%
p.zoom(10)
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
p.pan_rel((0.1, 0.1))
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds.r[(0.4,'Mpc'):0.6,:,:].profile(["density", "temperature"], "cell_mass", weight_field=None).plot()
# Out:
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
